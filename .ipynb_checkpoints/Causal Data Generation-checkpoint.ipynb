# %%
import numpy as np
import pandas as pd
import networkx as nx
from itertools import permutations
import graphviz
from collections import defaultdict

import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# generate graph

# %%
NUM_NODES     = 5
AFFINITY      = .5
MAX_LAG       = 5
TIME_AFFINITY = .1

# %%
dag = nx.DiGraph()
nodes = ['x%s_t%s' % (str(n+1), MAX_LAG) for n in range(NUM_NODES)]

# %%
edges = []
for edge in [i for i in list(permutations(nodes, 2))]:
    r = np.random.random()
    if r < AFFINITY:
        edges.append(edge)

# %%
dag.add_nodes_from(nodes)
dag.add_edges_from(edges)

# %%
while True:
    try:
        dag.remove_edges_from(nx.find_cycle(dag))
    except:
        break

# %%
dot = graphviz.Digraph()
for node in dag.nodes:
    dot.node(node)
    
for a, b in dag.edges:
    dot.edge(a, b)

# %%
dot

# %% [markdown]
# # Structural Equation Setup

# %%
class CausalAssignmentModel:
    """
    Basically just a hack to allow me to provide information about the
    arguments of a dynamically generated function.
    """
    def __init__(self, model, parents, params=None, weights=None):
        self.model   = model
        self.parents = parents
        self.params  = params
        self.weights = weights
        
    def __call__(self, *args, **kwargs):
        #assert len(args) == 0
        if self.params is not None:
            params = self.params+(n_samples,)
            return self.model(*params)
        
        elif self.params is None:
            return self.model(**kwargs)

    def __repr__(self):
        return "CausalAssignmentModel({})".format(",".join(self.parents))
    
def _binomial():
    var = np.random.random()
    return np.random.binomial, 1, var


def _normal():
    return np.random.normal,0 , 1

def _logistic():
    return np.random.logistic, 0,1

def _poisson():
    mu = np.random.randint(0,10)
    return np.random.poisson, mu

def _sigma(x):
    return 1 / (1 + np.exp(-x))

def logistic_model(parents, weights, offset=0):
    assert len(parents) == len(weights)
    assert len(parents) > 0
    
    def model(**kwargs):
        a = np.array([kwargs[p] * w for p, w in zip(parents, weights)])
        a = np.sum(a, axis=0) + offset
        a = _sigma(a)
        #a = np.random.binomial(n=1, p=a)
        return a
    
    return CausalAssignmentModel(model, parents , weights=weights)


def linear_model(parents, weights, offset=0, noise_scale=1):
    assert len(parents) == len(weights)
    assert len(parents) > 0    

    def model(**kwargs):
        n_samples = kwargs["n_samples"]
        a = np.array([kwargs[p] * w for p, w in zip(parents, weights)], dtype=np.float)
        a = np.sum(a, axis=0)
        a += np.random.normal(loc=offset, scale=noise_scale, size=n_samples)
        return a
    
    return CausalAssignmentModel(model, parents , weights=weights)

# %%
seeds  = [_binomial(), _normal(), _logistic(), _poisson()]
models = [logistic_model, linear_model]

assignments = {}

# %%
for g in nx.isolates(dag):
    print("Isolates: %s" % g)
    m = np.random.choice(seeds)
    assignments[g] = CausalAssignmentModel(m[0], [], m[1:])

for i in nx.topological_sort(dag):
    
    parents = [k for k in dag.predecessors(i)]
    print(i, parents)
    if len(parents) == 0:
        #print("Root: %s" % i)
        m = np.random.choice(seeds)
        assignments[i] = CausalAssignmentModel(m[0], [], m[1:])
        
    elif len(parents) > 0:
        #print("Child: %s" % i)
        num_weights = len(parents)
        model = np.random.choice(models)
        assignments[i] = model(parents, [np.random.random() for par in range(num_weights)])
# Out:
# x5_t5 []
# x2_t5 ['x5_t5']
# x1_t5 []
# x4_t5 ['x1_t5', 'x2_t5', 'x5_t5']
# x3_t5 ['x1_t5', 'x4_t5']

# %%
dot

# %% [markdown]
# # Generate Temporal Lags and Equations

# %%
TIME_AFFINITY=.03
print(TIME_AFFINITY)
print(MAX_LAG)
# Out:
# 0.03
# 5

# %%
list(reversed(range(0,MAX_LAG-1)))
# Out:
# [3, 2, 1, 0]

# %%
lagged_equations = []

for i in reversed(range(1,MAX_LAG-1)):
    lag_connections = []
    for current_node in dag.nodes:
        for lagged_node in dag.nodes:
            n = lagged_node.split('_')[0]
            r = np.random.random()
            if r < TIME_AFFINITY:
                edge = ('%s_t%s' % (n, i), current_node)
                lag_connections.append(edge)
    lagged_equations.append(lag_connections)

# %%
#print(list(reversed(range(1,MAX_LAG))))
lagged_equations
# Out:
# [[('x4_t3', 'x3_t5')], [], []]

# %%
# list(reversed(range(1,MAX_LAG)))
# draw graph for presentation 

# best way to store data
# node (x4), lagged_descendents = [x4_t1, x3_t2], lagged_models
# use similar

# %%
lagged_assignments = defaultdict(list)

for lag in lagged_equations:
    for e in lag:
        model = np.random.choice(models)
        lagged_assignments[e[1]].append(e[0])

# %%
lagged_sem = {}

for n, parents in lagged_assignments.items():
    num_weights = len(parents)
    model = linear_model # np.random.choice(models)
    lagged_sem[n] = model(parents, [np.random.random() for par in range(num_weights)])

# %%
lagged_sem
# Out:
# {'x3_t5': CausalAssignmentModel(x4_t3)}

# %%
lagged_assignments
# Out:
# defaultdict(list, {'x3_t5': ['x4_t3']})

# %%
lag_dag = nx.DiGraph()

# %%
lag_dag.add_nodes_from(dag.nodes)

# %%
for lag in lagged_equations:
    for e in lag:
        lag_dag.add_node(e[0])
        lag_dag.add_edge(e[0], e[1])

# %%
dot = graphviz.Digraph()
for node in lag_dag.nodes:
    dot.node(node)
for a, b in lag_dag.edges:
    dot.edge(a, b)
    
dot

# %%
# how to sample

# %%
#final_graph = nx.DiGraph()

# %%
#for tg in time_graphs:
#    final_graph.add_nodes_from(tg.nodes)
#    final_graph.add_edges_from(tg.edges)
    
#final_graph.add_edges_from(future_edges)

# %%
#dot = graphviz.Digraph()

##for node in final_graph.nodes:
#    dot.node(node)
    
#for a, b in final_graph.edges:
#    dot.edge(a, b)
    
#dot

# %% [markdown]
# # Generate: Structural Model

# %%
#assignments['x4_t5'].model(**parent_samples)

# %%
dot = graphviz.Digraph()
for node in nodes:
    dot.node(node)
    
for a, b in dag.edges:
    dot.edge(a, b)
    
dot

# %%
for node in nx.topological_sort(dag):
    print(node)
# Out:
# x5_t5
# x2_t5
# x1_t5
# x4_t5
# x3_t5

# %%
samples = {}
n_samples = MAX_LAG-1

for node in nx.topological_sort(dag):
    c_model = assignments[node]

    parent_samples = {
        parent: samples[parent]
        for parent in c_model.parents
    }
    
    parent_samples["n_samples"] = n_samples
    #print(node, parent_samples)
    samples[node] = c_model(**parent_samples)

# %%
output = pd.DataFrame(samples)
output.columns = [x.split('_')[0] for x in output.columns]
output
# Out:
#    x5        x2        x1        x4        x3
# 0   0 -0.202552 -0.583579  0.368588  0.449705
# 1   0 -1.058166  4.759004  0.970884  0.946378
# 2   0 -0.126568  0.810256  0.648975  0.654232
# 3   0 -1.084631 -1.152975  0.216461  0.364380

# %%
new_samples = {}
n_samples = 1
rows = 100

for row in range(rows):
    for node in nx.topological_sort(dag):
        c_model = assignments[node]
        parent_samples = {
            parent: new_samples[parent]
            for parent in c_model.parents
        }

        parent_samples["n_samples"] = n_samples
        new_samples[node] = c_model(**parent_samples)
    
    for child, parents in lagged_sem.items():
        c_model  = parents
        exes     = [ex.split('_')[0] for ex in parents.parents]
        pos      = [ex.split('_')[1] for ex in parents.parents]
        values   = [output[loc[0]][int(loc[1].split('t')[1])] for loc in zip(exes, pos)]
        new_dict = dict(zip(parents.parents, values))
        new_dict["n_samples"] = n_samples
        new_samples[child] = c_model.model(**new_dict)
        
    append = pd.DataFrame(new_samples)
    append.columns = [x.split('_')[0] for x in append.columns]
    
    output = output.append(append, ignore_index=True)

# %%
output=output[MAX_LAG:]

# %%
output
# Out:
#      x5        x2        x1        x4        x3
# 5     0  0.617182 -1.294333  0.300166 -1.154472
# 6     0 -0.092329 -1.155244  0.275870 -0.251272
# 7     0 -2.523904  1.443752  0.585741  0.425568
# 8     0  0.329942  1.512066  0.791042 -0.580632
# 9     0 -1.156589 -1.259188  0.198482 -0.624049
# ..   ..       ...       ...       ...       ...
# 99    0  0.238774 -3.864473  0.045224 -0.100222
# 100   0  1.647804  0.844424  0.772086 -0.509628
# 101   0 -0.664090  0.720128  0.590616 -0.103228
# 102   0  3.183068 -0.311230  0.686733  0.873515
# 103   0  0.147881 -0.654589  0.381873  0.699499
#
# [99 rows x 5 columns]

# %%
import seaborn as sns
# Create the default pairplot
sns.pairplot(output)

# %%
dot = graphviz.Digraph()
for node in nodes:
    dot.node(node)
    
for a, b in dag.edges:
    dot.edge(a, b)
    
dot

# %%
plt.plot(output['x3'])

# %%
plt.hist(output['x1'])
# Out:
# (array([ 3.,  6., 10., 20., 30., 13.,  9.,  3.,  2.,  3.]),
#  array([0.41229228, 0.43273838, 0.45318447, 0.47363057, 0.49407666,
#         0.51452275, 0.53496885, 0.55541494, 0.57586104, 0.59630713,
#         0.61675323]),
#  <a list of 10 Patch objects>)

# %%
plt.hist(output['x2'])
# Out:
# (array([ 4., 15., 15., 33.,  7., 15.,  8.,  1.,  0.,  1.]),
#  array([ 0. ,  1.6,  3.2,  4.8,  6.4,  8. ,  9.6, 11.2, 12.8, 14.4, 16. ]),
#  <a list of 10 Patch objects>)

# %%
plt.hist(output['x3'])
# Out:
# (array([ 3.,  6., 10., 20., 30., 14.,  8.,  4.,  1.,  3.]),
#  array([-4.08750569, -3.13014889, -2.17279209, -1.21543528, -0.25807848,
#          0.69927833,  1.65663513,  2.61399193,  3.57134874,  4.52870554,
#          5.48606235]),
#  <a list of 10 Patch objects>)

# %%
plt.hist(output['x4'])
# Out:
# (array([ 4., 10., 17., 16.,  9., 18., 17.,  5.,  2.,  1.]),
#  array([-1.89871436, -1.44123079, -0.98374722, -0.52626364, -0.06878007,
#          0.38870351,  0.84618708,  1.30367065,  1.76115423,  2.2186378 ,
#          2.67612138]),
#  <a list of 10 Patch objects>)

# %%
plt.hist(output['x5'])
# Out:
# (array([ 2.,  6., 13., 21., 18., 14., 18.,  3.,  2.,  2.]),
#  array([-3.81037334, -2.93554234, -2.06071134, -1.18588034, -0.31104933,
#          0.56378167,  1.43861267,  2.31344367,  3.18827467,  4.06310567,
#          4.93793667]),
#  <a list of 10 Patch objects>)

# %%
new_samples = {}
n_samples = 1
rows = 100

for node in nx.topological_sort(dag):
    c_model = assignments[node]
    parent_samples = {
        parent: new_samples[parent]
        for parent in c_model.parents
    }

    parent_samples["n_samples"] = n_samples
    new_samples[node] = c_model(**parent_samples)

print(new_samples)

for child, parents in lagged_sem.items():
    c_model = parents
    exes = [ex.split('_')[0] for ex in parents.parents]
    pos    = [ex.split('_')[1] for ex in parents.parents]
    values = [output[loc[0]][int(loc[1].split('t')[1])] for loc in zip(exes, pos)]
    new_dict = dict(zip(parents.parents, values))
    new_dict["n_samples"] = n_samples
    new_samples[child] = c_model.model(**new_dict)
    
print(new_samples)
